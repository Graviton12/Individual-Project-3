# %% [markdown]
# # Individual Project 3 - Working with MatplotLib and Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ### 1. Create a simple plot using plt.plot(). Plot a single Python list [3,7,8,9,12].

# %%
list1 = [3,7,8,9,12]
# plotting list using plot()
plt.plot(list1)
plt.show()

# %% [markdown]
# ### 2. Create two lists, one called x, one called y, each with 5 numbers in them
# a. Plot them using plt.plot().

# %%
x = [9,17,19,23,30]
y = [12,15,24,28,39]
# plotting x list and y list using plot()
plt.plot(x,y)
plt.show()

# %% [markdown]
# b. Create a plot using plt.subplots() and then add x & y on the axes.

# %%
# creating a figure and axis using subplots()
fig,ax=plt.subplots()
# plotting x list and y lsit
ax.plot(x,y)
# adding x axis label and y axis label using set_xlabel and set_ylabel
ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
plt.show()

# %% [markdown]
# ### 3. Create an 1D array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable X.

# %%
# creating a numpy array that ranges from 0 to 100 with 100 even spaces
X = np.linspace(0,100,100)
# calling X to see what it looks like
X
# Out:
# array([  0.        ,   1.01010101,   2.02020202,   3.03030303,
#          4.04040404,   5.05050505,   6.06060606,   7.07070707,
#          8.08080808,   9.09090909,  10.1010101 ,  11.11111111,
#         12.12121212,  13.13131313,  14.14141414,  15.15151515,
#         16.16161616,  17.17171717,  18.18181818,  19.19191919,
#         20.2020202 ,  21.21212121,  22.22222222,  23.23232323,
#         24.24242424,  25.25252525,  26.26262626,  27.27272727,
#         28.28282828,  29.29292929,  30.3030303 ,  31.31313131,
#         32.32323232,  33.33333333,  34.34343434,  35.35353535,
#         36.36363636,  37.37373737,  38.38383838,  39.39393939,
#         40.4040404 ,  41.41414141,  42.42424242,  43.43434343,
#         44.44444444,  45.45454545,  46.46464646,  47.47474747,
#         48.48484848,  49.49494949,  50.50505051,  51.51515152,
#         52.52525253,  53.53535354,  54.54545455,  55.55555556,
#         56.56565657,  57.57575758,  58.58585859,  59.5959596 ,
# ...

# %% [markdown]
# a. Create a plot using plt.subplots() and plot X versus X^2

# %%
# creating variable which is X squared
square_X = X**2
# creating figure and axis with subplots()
fig,ax1=plt.subplots()

# plotting X and X squared
ax1.plot(X, square_X)
# adding x xis label and y axis label using set_xlabel adn set_ylabel and adding title
ax1.set_xlabel('X')
ax1.set_ylabel('X^2')
ax1.set_title('X vs. X^2')

plt.show()

# %% [markdown]
# b. Create a scatter plot of X versus the exponential of X (np.exp(X))

# %%
# creating variable with exponential of X
exponent_X = np.exp(X)
# creating scatter plot with X and exponential of X
plt.scatter(X, exponent_X)

# adding axis labels and title
plt.xlabel('X')
plt.ylabel('Exponential of X')
plt.title('X vs. Exponential X')

plt.show()

# %% [markdown]
# ### 4. Import car-sales.csv  into a DataFrame called car_sales and view.

# %%
# reading car_sales css
car_sales=pd.read_csv('car-sales.csv')
# viwing car_sales DataFrame
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   $4,000
# 1   Honda    Red          87899      4   $5,000
# 2  Toyota   Blue          32549      3   $7,000
# 3     BMW  Black          11179      5  $22,000
# 4  Nissan  White         213095      4   $3,500

# %%
# checking information about car_sales
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# a. Try to plot the 'Price' column using the plot() function

# %%
# will produce an error
car_sales['Price'].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # will produce an error
# ----> 2 car_sales['Price'].plot()
#       3 plt.show()
#
# File ~\Anaconda3\envs\DS160\lib\site-packages\pandas\plotting\_core.py:1031, in PlotAccessor.__call__(self, *args, **kwargs)
#    1028             label_name = label_kw or data.columns
#    1029             data.columns = label_name
# -> 1031 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\Anaconda3\envs\DS160\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %% [markdown]
# b. Try to plot the ''Odometer (KM)” column using the plot() function

# %%
# will not produce an error
car_sales['Odometer (KM)'].plot()
plt.show()

# %% [markdown]
# Trying to plot the 'Price' column does not work while trying to plot the 'Odometer (KM)' column does work. This is because the 'Price' column is an object data type so there is no numerical data to plot. The 'Odometer (KM)' column is an integer data type so there is numerical data to plot.

# %% [markdown]
# ### 5. Remove all the symbols (\$\) from the 'Price' column and convert  and update it to  64-bit int numbers using astype(‘int64’) Hint. Look for string functions like replace/strip).

# %%
# str.replace() is used to get rid of the $ symbol and the commas. 
# regex=True is used to ensure that the passed in pattern in a regular expression
# astype('int64') is used to cast a pandas object to a specified data type. the dtype is int64
car_sales['Price'] = car_sales['Price'].str.replace('[\$,]', '', regex=True).astype('int64')

# %% [markdown]
# ### 6.	Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column look up the cumsum() function.

# %%
# using cumsum() to take the price from the previous to add tot he price of the next row. A cumulative sum.
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# %%
# checking to see if Total Sales was added
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500

# %% [markdown]
# ### 7.	Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today). Check out “date_range” function and keep the periods=len(car_sales).

# %%
# importing datetime 
from datetime import datetime

# %%
# using date_range to return a range of equally spaced time points
# start is the left bound and is the current date
# period is the number of periods to generate which refers to the length of the columns
# this creates a series of successive dates starting from today
date_range=pd.date_range(start=datetime.now(), periods=len(car_sales))

# %%
# creating the Sale Date column and setting it equal to date_range
car_sales['Sale Date'] = date_range

# %%
# checking to see if Sale Date has been added
car_sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  \
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
#
#                    Sale Date
# 0 2023-10-04 13:29:28.736783
# 1 2023-10-05 13:29:28.736783
# 2 2023-10-06 13:29:28.736783
# 3 2023-10-07 13:29:28.736783
# 4 2023-10-08 13:29:28.736783
# 5 2023-10-09 13:29:28.736783

# %% [markdown]
# ### 8. Use the matplotlib line plot function to plot the 'Price' column versus the 'Total Sales' column (Give proper title and appropriate labels).

# %%
# using plot() to create line plot of Price and Total Sales
plt.plot(car_sales['Price'], car_sales['Total Sales'])
# adding axis labels and title
plt.xlabel('Price')
plt.ylabel('Sales Price')
plt.title('Price Vs. Total Sales Line Plot')
plt.show()

# %% [markdown]
# ### 9. Create a matplotlib scatter plot of the 'Odometer (KM)' vs 'Price' column.

# %%
# creating scatter plot of Odometer (KM) and Price
plt.scatter(car_sales['Odometer (KM)'],car_sales['Price'])
# adding axis labels and title
plt.xlabel('Odometer (KM)')
plt.ylabel('Price')
plt.title('Odometer (KM) vs. Price Scatter Plot')
plt.show()

# %% [markdown]
# ### 10.	Create a matplotlib bar graph of the 'Make' vs 'Odometer (KM)' columns

# %%
# creating a bar plot of the Make and Odometer (KM)
plt.bar(car_sales['Make'], car_sales['Odometer (KM)'])
# adding axis labels and title
plt.xlabel('Make')
plt.ylabel('Odometer (KM)')
plt.title('Make vs. Odometer (KM) Bar Plot')
plt.show()

# %% [markdown]
# ### 11.	Create a histogram of the 'Make' column

# %%
# creating a histogram of the Make
plt.hist(car_sales['Make'])
# adding axis labels and titles
plt.xlabel('Make')
plt.ylabel('Frequency')
plt.title('Histogram of Car Make')
plt.show()

# %% [markdown]
# ### 12.	Create a subplot of multiple plots (step 8,9,10,11)

# %%
# creating a figure with a size of 14 by 14
fig=plt.figure(figsize=(14,14))

# creating first plot
ax1=fig.add_subplot(221)
ax1.plot(car_sales['Price'], car_sales['Total Sales'])
# adding axis labels and title to first plot
ax1.set_xlabel('Price')
ax1.set_ylabel('Sales Price')
ax1.set_title('Price Vs. Total Sales Line Plot')

# creating second plot
ax2=fig.add_subplot(222)
ax2.scatter(car_sales['Odometer (KM)'],car_sales['Price'])
# adding axis labels and title to second plot
ax2.set_xlabel('Odometer (KM)')
ax2.set_ylabel('Price')
ax2.set_title('Odometer (KM) vs. Price Scatter Plot')

# creating third plot
ax3=fig.add_subplot(223)
ax3.bar(car_sales['Make'], car_sales['Odometer (KM)'])
# adding axis labels and title to third plot
ax3.set_xlabel('Make')
ax3.set_ylabel('Odometer (KM)')
ax3.set_title('Make vs. Odometer (KM) Bar Plot')

# creating fourth plot
ax4=fig.add_subplot(224)
ax4.hist(car_sales['Make'])
# adding axis labels and titles to foruth plot
ax4.set_xlabel('Make')
ax4.set_ylabel('Frequency')
ax4.set_title('Histogram of Car Make')

plt.show()

# %% [markdown]
# ### 13.	Create a box plot of Colour and Total Sales using seaborn plot

# %%
# creating box plot
sns.boxplot(x='Colour', y='Total Sales', data=car_sales)
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Colour', ylabel='Total Sales'>

# %% [markdown]
# ### 14.	Find out the relationship between "Total Sales" and "Odometer (KM)" using linear regression with no error bar and car make will determine the hue

# %%
sns.lmplot(x='Total Sales', y='Odometer (KM)', data=car_sales, ci=False, hue='Make')
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### 15.	Draw pair plot for all possible combinations

# %%
sns.pairplot(car_sales)
# Out:
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\smahmood\Anaconda3\envs\DS160\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### 16.	Find out Pearson correlation between 'Total Sales','Price','Odometer (KM)'. Comment on the correlation

# %%
heat_map=car_sales[['Total Sales', 'Price', 'Odometer (KM)']].corr(method='pearson')
cols=['Total Sales', 'Price', 'Odometer (KM)']
sns.heatmap(heat_map, xticklabels=cols, yticklabels=cols, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# There is a weak positive correlation between price and total sales. There is a relatively weak negative correlation between the odometer (KM) and total sales. There is a relatively strong negative correlation between price and the odometer (KM).
